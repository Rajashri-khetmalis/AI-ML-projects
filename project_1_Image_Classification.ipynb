# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajashri-khetmalis/AI-ML-projects/blob/main/project_1_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/fruit.csv")

# %%
df
# Out:
#     1  192  8.4   7.3  0.55      apple
# 0   1  180  8.0   6.8  0.59      apple
# 1   1  176  7.4   7.2  0.60      apple
# 2   2   86  6.2   4.7  0.80   mandarin
# 3   2   84  6.0   4.6  0.79   mandarin
# 4   2   80  5.8   4.3  0.77  mandarin
# 5   2   80  5.9   4.3  0.81  mandarin
# 6   2   76  5.8   4.0  0.81   mandarin
# 7   1  178  7.1   7.8  0.92      apple
# 8   1  172  7.4   7.0  0.89      apple
# 9   1  166  6.9   7.3  0.93      apple
# 10  1  172  7.1   7.6  0.92      apple
# 11  1  154  7.0   7.1  0.88      apple
# 12  1  164  7.3   7.7  0.70      apple
# 13  1  152  7.6   7.3  0.69      apple
# 14  1  156  7.7   7.1  0.69      apple
# 15  1  156  7.6   7.5  0.67      apple
# 16  1  168  7.5   7.6  0.73      apple
# 17  1  162  7.5   7.1  0.83      apple
# 18  1  162  7.4   7.2  0.85      apple
# 19  1  160  7.5   7.5  0.86      apple
# 20  1  156  7.4   7.4  0.84      apple
# 21  1  140  7.3   7.1  0.87      apple
# 22  1  170  7.6   7.9  0.88      apple
# 23  3  342  9.0   9.4  0.75     orange
# 24  3  356  9.2   9.2  0.75     orange
# 25  3  362  9.6   9.2  0.74     orange
# 26  3  204  7.5   9.2  0.77     orange
# 27  3  140  6.7   7.1  0.72     orange
# 28  3  160  7.0   7.4  0.81     orange
# 29  3  158  7.1   7.5  0.79     orange
# 30  3  210  7.8   8.0  0.82     orange
# 31  3  164  7.2   7.0  0.80     orange
# 32  3  190  7.5   8.1  0.74     orange
# 33  3  142  7.6   7.8  0.75     orange
# 34  3  150  7.1   7.9  0.75     orange
# 35  3  160  7.1   7.6  0.76     orange
# 36  3  154  7.3   7.3  0.79     orange
# 37  3  158  7.2   7.8  0.77     orange
# 38  3  144  6.8   7.4  0.75     orange
# 39  3  154  7.1   7.5  0.78     orange
# 40  3  180  7.6   8.2  0.79     orange
# 41  3  154  7.2   7.2  0.82     orange
# 42  4  194  7.2  10.3  0.70      lemon
# 43  4  200  7.3  10.5  0.72      lemon
# 44  4  186  7.2   9.2  0.72      lemon
# 45  4  216  7.3  10.2  0.71      lemon
# 46  4  196  7.3   9.7  0.72      lemon
# 47  4  174  7.3  10.1  0.72      lemon
# 48  4  132  5.8   8.7  0.73      lemon
# 49  4  130  6.0   8.2  0.71      lemon
# 50  4  116  6.0   7.5  0.72      lemon
# 51  4  118  5.9   8.0  0.72      lemon
# 52  4  120  6.0   8.4  0.74      lemon
# 53  4  116  6.1   8.5  0.71      lemon
# 54  4  116  6.3   7.7  0.72      lemon
# 55  4  116  5.9   8.1  0.73      lemon
# 56  4  152  6.5   8.5  0.72      lemon
# 57  4  118  6.1   8.1  0.70      lemon

# %%
features=df.iloc[:,:5]
label=df.iloc[:,5]

print(features)
print(label)
# Out:
#     1  192  8.4   7.3  0.55
# 0   1  180  8.0   6.8  0.59
# 1   1  176  7.4   7.2  0.60
# 2   2   86  6.2   4.7  0.80
# 3   2   84  6.0   4.6  0.79
# 4   2   80  5.8   4.3  0.77
# 5   2   80  5.9   4.3  0.81
# 6   2   76  5.8   4.0  0.81
# 7   1  178  7.1   7.8  0.92
# 8   1  172  7.4   7.0  0.89
# 9   1  166  6.9   7.3  0.93
# 10  1  172  7.1   7.6  0.92
# 11  1  154  7.0   7.1  0.88
# 12  1  164  7.3   7.7  0.70
# 13  1  152  7.6   7.3  0.69
# 14  1  156  7.7   7.1  0.69
# 15  1  156  7.6   7.5  0.67
# 16  1  168  7.5   7.6  0.73
# 17  1  162  7.5   7.1  0.83
# 18  1  162  7.4   7.2  0.85
# 19  1  160  7.5   7.5  0.86
# 20  1  156  7.4   7.4  0.84
# 21  1  140  7.3   7.1  0.87
# 22  1  170  7.6   7.9  0.88
# 23  3  342  9.0   9.4  0.75
# 24  3  356  9.2   9.2  0.75
# 25  3  362  9.6   9.2  0.74
# 26  3  204  7.5   9.2  0.77
# 27  3  140  6.7   7.1  0.72
# 28  3  160  7.0   7.4  0.81
# 29  3  158  7.1   7.5  0.79
# 30  3  210  7.8   8.0  0.82
# 31  3  164  7.2   7.0  0.80
# 32  3  190  7.5   8.1  0.74
# 33  3  142  7.6   7.8  0.75
# 34  3  150  7.1   7.9  0.75
# 35  3  160  7.1   7.6  0.76
# 36  3  154  7.3   7.3  0.79
# 37  3  158  7.2   7.8  0.77
# 38  3  144  6.8   7.4  0.75
# 39  3  154  7.1   7.5  0.78
# 40  3  180  7.6   8.2  0.79
# 41  3  154  7.2   7.2  0.82
# 42  4  194  7.2  10.3  0.70
# 43  4  200  7.3  10.5  0.72
# 44  4  186  7.2   9.2  0.72
# 45  4  216  7.3  10.2  0.71
# 46  4  196  7.3   9.7  0.72
# 47  4  174  7.3  10.1  0.72
# 48  4  132  5.8   8.7  0.73
# 49  4  130  6.0   8.2  0.71
# 50  4  116  6.0   7.5  0.72
# 51  4  118  5.9   8.0  0.72
# 52  4  120  6.0   8.4  0.74
# 53  4  116  6.1   8.5  0.71
# 54  4  116  6.3   7.7  0.72
# 55  4  116  5.9   8.1  0.73
# 56  4  152  6.5   8.5  0.72
# 57  4  118  6.1   8.1  0.70
# 0         apple
# 1         apple
# 2      mandarin
# 3      mandarin
# 4     mandarin
# 5     mandarin
# 6      mandarin
# 7         apple
# 8         apple
# 9         apple
# 10        apple
# 11        apple
# 12        apple
# 13        apple
# 14        apple
# 15        apple
# 16        apple
# 17        apple
# 18        apple
# 19        apple
# 20        apple
# 21        apple
# 22        apple
# 23       orange
# 24       orange
# 25       orange
# 26       orange
# 27       orange
# 28       orange
# 29       orange
# 30       orange
# 31       orange
# 32       orange
# 33       orange
# 34       orange
# 35       orange
# 36       orange
# 37       orange
# 38       orange
# 39       orange
# 40       orange
# 41       orange
# 42        lemon
# 43        lemon
# 44        lemon
# 45        lemon
# 46        lemon
# 47        lemon
# 48        lemon
# 49        lemon
# 50        lemon
# 51        lemon
# 52        lemon
# 53        lemon
# 54        lemon
# 55        lemon
# 56        lemon
# 57        lemon
# Name:   apple, dtype: object

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,label,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

clf=LogisticRegression()

clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
predict=clf.predict([[1	,180,	8.0,6.8,	0.59	]])
print(" ".join(predict))
# Out:
# apple
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
